# %%
import pandas as pd

# %%
inputDF = pd.read_csv('Train.csv')

# %%
col_temp = []
for i in inputDF.columns:
    col_temp.append(i.replace('.','_'))
inputDF.columns = col_temp

# %%
inputDF
# Out:
#        BOROUGH NEIGHBORHOOD                      BUILDING_CLASS_CATEGORY  \
# 0            3          N36  01 ONE FAMILY DWELLINGS
# 1            3          N81   10 COOPS  ELEVATOR APARTMENTS
# 2            4          N13  02 TWO FAMILY DWELLINGS
# 3            5         N103  02 TWO FAMILY DWELLINGS
# 4            3          N20  02 TWO FAMILY DWELLINGS
# 5            5         N103  01 ONE FAMILY DWELLINGS
# 6            5         N170  01 ONE FAMILY DWELLINGS
# 7            4          N91  01 ONE FAMILY DWELLINGS
# 8            4          N88  01 ONE FAMILY DWELLINGS
# 9            2          N90  02 TWO FAMILY DWELLINGS
# 10           3          N20   07 RENTALS  WALKUP APARTMENTS
# 11           3          N15  01 ONE FAMILY DWELLINGS
# 12           4         N119  01 ONE FAMILY DWELLINGS
# 13           3          N85  01 ONE FAMILY DWELLINGS
# 14           4         N195  01 ONE FAMILY DWELLINGS
# 15           3         N206  04 TAX CLASS 1 CONDOS
# ...
